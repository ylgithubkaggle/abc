# %%
import pandas # PAnel DAtaS
dataframe=pandas.read_csv('python-novice-gapminder-data/data/gapminder_all.csv')

# %%
print(dataframe)
# Out:
#     continent                   country  gdpPercap_1952  gdpPercap_1957  \
# 0      Africa                   Algeria     2449.008185     3013.976023
# 1      Africa                    Angola     3520.610273     3827.940465
# 2      Africa                     Benin     1062.752200      959.601080
# 3      Africa                  Botswana      851.241141      918.232535
# 4      Africa              Burkina Faso      543.255241      617.183465
# 5      Africa                   Burundi      339.296459      379.564628
# 6      Africa                  Cameroon     1172.667655     1313.048099
# 7      Africa  Central African Republic     1071.310713     1190.844328
# 8      Africa                      Chad     1178.665927     1308.495577
# 9      Africa                   Comoros     1102.990936     1211.148548
# 10     Africa           Congo Dem. Rep.      780.542326      905.860230
# 11     Africa                Congo Rep.     2125.621418     2315.056572
# ...

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 38 columns):
# continent         142 non-null object
# country           142 non-null object
# gdpPercap_1952    142 non-null float64
# gdpPercap_1957    142 non-null float64
# gdpPercap_1962    142 non-null float64
# gdpPercap_1967    142 non-null float64
# gdpPercap_1972    142 non-null float64
# gdpPercap_1977    142 non-null float64
# gdpPercap_1982    142 non-null float64
# gdpPercap_1987    142 non-null float64
# gdpPercap_1992    142 non-null float64
# gdpPercap_1997    142 non-null float64
# gdpPercap_2002    142 non-null float64
# gdpPercap_2007    142 non-null float64
# lifeExp_1952      142 non-null float64
# lifeExp_1957      142 non-null float64
# lifeExp_1962      142 non-null float64
# lifeExp_1967      142 non-null float64
# lifeExp_1972      142 non-null float64
# lifeExp_1977      142 non-null float64
# lifeExp_1982      142 non-null float64
# ...

# %%
dataframe1 = dataframe[['continent','country']]
print(dataframe1)
# Out:
#     continent                   country
# 0      Africa                   Algeria
# 1      Africa                    Angola
# 2      Africa                     Benin
# 3      Africa                  Botswana
# 4      Africa              Burkina Faso
# 5      Africa                   Burundi
# 6      Africa                  Cameroon
# 7      Africa  Central African Republic
# 8      Africa                      Chad
# 9      Africa                   Comoros
# 10     Africa           Congo Dem. Rep.
# 11     Africa                Congo Rep.
# 12     Africa             Cote d'Ivoire
# 13     Africa                  Djibouti
# 14     Africa                     Egypt
# 15     Africa         Equatorial Guinea
# 16     Africa                   Eritrea
# 17     Africa                  Ethiopia
# 18     Africa                     Gabon
# 19     Africa                    Gambia
# 20     Africa                     Ghana
# 21     Africa                    Guinea
# ...

# %%
print(dataframe.columns[1])
print(dataframe.columns[2])
print(dataframe.columns)
# Out:
# country
# gdpPercap_1952
# Index(['continent', 'country', 'gdpPercap_1952', 'gdpPercap_1957',
#        'gdpPercap_1962', 'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977',
#        'gdpPercap_1982', 'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997',
#        'gdpPercap_2002', 'gdpPercap_2007', 'lifeExp_1952', 'lifeExp_1957',
#        'lifeExp_1962', 'lifeExp_1967', 'lifeExp_1972', 'lifeExp_1977',
#        'lifeExp_1982', 'lifeExp_1987', 'lifeExp_1992', 'lifeExp_1997',
#        'lifeExp_2002', 'lifeExp_2007', 'pop_1952', 'pop_1957', 'pop_1962',
#        'pop_1967', 'pop_1972', 'pop_1977', 'pop_1982', 'pop_1987', 'pop_1992',
#        'pop_1997', 'pop_2002', 'pop_2007'],
#       dtype='object')

# %% [markdown]
# ### How to transpose a data frame

# %%
dataframe.T
# Out:
#                         0            1            2            3    \
# continent            Africa       Africa       Africa       Africa
# country             Algeria       Angola        Benin     Botswana
# gdpPercap_1952      2449.01      3520.61      1062.75      851.241
# gdpPercap_1957      3013.98      3827.94      959.601      918.233
# gdpPercap_1962      2550.82      4269.28      949.499      983.654
# gdpPercap_1967      3246.99      5522.78      1035.83      1214.71
# gdpPercap_1972      4182.66      5473.29       1085.8      2263.61
# gdpPercap_1977      4910.42      3008.65      1029.16      3214.86
# gdpPercap_1982      5745.16      2756.95       1277.9      4551.14
# gdpPercap_1987      5681.36      2430.21      1225.86      6205.88
# gdpPercap_1992      5023.22      2627.85      1191.21      7954.11
# gdpPercap_1997       4797.3      2277.14      1232.98      8647.14
# gdpPercap_2002      5288.04      2773.29      1372.88      11003.6
# ...

# %%
dataframe.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count      142.000000      142.000000      142.000000      142.000000
# mean      3725.276046     4299.408345     4725.812342     5483.653047
# std       9321.064786     9869.662202     8667.362525     8095.315431
# min        298.846212      335.997115      355.203227      349.000000
# 25%        864.752389      930.540819     1059.149171     1151.245103
# 50%       1968.528344     2173.220291     2335.439533     2678.334741
# 75%       3913.492777     4876.356362     5709.381428     7075.932943
# max     108382.352900   113523.132900    95458.111760    80894.883260
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count      142.000000      142.000000      142.000000      142.000000
# mean      6770.082815     7313.166421     7518.901673     7900.920218
# std      10614.383403     8362.489150     7733.845006     8288.281304
# ...

# %%
dataframe.head()
# Out:
#   continent       country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Africa       Algeria     2449.008185     3013.976023     2550.816880
# 1    Africa        Angola     3520.610273     3827.940465     4269.276742
# 2    Africa         Benin     1062.752200      959.601080      949.499064
# 3    Africa      Botswana      851.241141      918.232535      983.653976
# 4    Africa  Burkina Faso      543.255241      617.183465      722.512021
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     3246.991771     4182.663766     4910.416756     5745.160213
# 1     5522.776375     5473.288005     3008.647355     2756.953672
# 2     1035.831411     1085.796879     1029.161251     1277.897616
# 3     1214.709294     2263.611114     3214.857818     4551.142150
# 4      794.826560      854.735976      743.387037      807.198586
#
#    gdpPercap_1987    ...       pop_1962    pop_1967    pop_1972    pop_1977  \
# ...

# %%
dataframe.tail()
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
#      gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 137    22966.144320     27195.11304    26982.290520    28397.715120
# 138     2826.356387      3450.69638     4269.122326     4241.356344
# 139    14142.850890     15895.11641    17428.748460    18232.424520
# 140    14526.124650     16788.62948    18334.197510    19477.009280
# 141    14463.918930     16046.03728    16233.717700    17632.410400
#
#      gdpPercap_1987    ...       pop_1962    pop_1967    pop_1972    pop_1977  \
# ...

# %%
dataframe.T.head().describe()
# Out:
#                 0       1          2           3           4       5    \
# count      5.000000       5    5.00000    5.000000    5.000000       5
# unique     5.000000       5    5.00000    5.000000    5.000000       5
# top     3013.976023  Angola  959.60108  983.653976  543.255241  Africa
# freq       1.000000       1    1.00000    1.000000    1.000000       1
#
#                 6            7            8            9       ...       \
# count      5.000000     5.000000     5.000000     5.000000     ...
# unique     5.000000     5.000000     5.000000     5.000000     ...
# top     1172.667655  1071.310713  1308.495577  1102.990936     ...
# freq       1.000000     1.000000     1.000000     1.000000     ...
#
#            132              133          134         135          136  \
# count        5                5     5.000000     5.00000     5.000000
# unique       5                5     5.000000     5.00000     5.000000
# ...

# %%
# A dataframe consists of a number of series
dataframe.mean()
# Out:
# gdpPercap_1952    3.725276e+03
# gdpPercap_1957    4.299408e+03
# gdpPercap_1962    4.725812e+03
# gdpPercap_1967    5.483653e+03
# gdpPercap_1972    6.770083e+03
# gdpPercap_1977    7.313166e+03
# gdpPercap_1982    7.518902e+03
# gdpPercap_1987    7.900920e+03
# gdpPercap_1992    8.158609e+03
# gdpPercap_1997    9.090175e+03
# gdpPercap_2002    9.917848e+03
# gdpPercap_2007    1.168007e+04
# lifeExp_1952      4.905762e+01
# lifeExp_1957      5.150740e+01
# lifeExp_1962      5.360925e+01
# lifeExp_1967      5.567829e+01
# lifeExp_1972      5.764739e+01
# lifeExp_1977      5.957016e+01
# lifeExp_1982      6.153320e+01
# lifeExp_1987      6.321261e+01
# lifeExp_1992      6.416034e+01
# lifeExp_1997      6.501468e+01
# lifeExp_2002      6.569492e+01
# lifeExp_2007      6.700742e+01
# pop_1952          1.695040e+07
# pop_1957          1.876341e+07
# pop_1962          2.042101e+07
# pop_1967          2.265830e+07
# pop_1972          2.518998e+07
# pop_1977          2.767638e+07
# ...

# %%
dataframe.iloc[0:3,0:20]
# Out:
#   continent  country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Africa  Algeria     2449.008185     3013.976023     2550.816880
# 1    Africa   Angola     3520.610273     3827.940465     4269.276742
# 2    Africa    Benin     1062.752200      959.601080      949.499064
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     3246.991771     4182.663766     4910.416756     5745.160213
# 1     5522.776375     5473.288005     3008.647355     2756.953672
# 2     1035.831411     1085.796879     1029.161251     1277.897616
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     5681.358539     5023.216647     4797.295051     5288.040382
# 1     2430.208311     2627.845685     2277.140884     2773.287312
# 2     1225.856010     1191.207681     1232.975292     1372.877931
#
#    gdpPercap_2007  lifeExp_1952  lifeExp_1957  lifeExp_1962  lifeExp_1967  \
# 0     6223.367465        43.077        45.685        48.303        51.407
# ...

# %%
dataframe.iloc[0:4,4]
# Out:
# 0    2550.816880
# 1    4269.276742
# 2     949.499064
# 3     983.653976
# Name: gdpPercap_1962, dtype: float64

# %%
dataframe=pandas.read_csv('python-novice-gapminder-data/data/gapminder_all.csv',index_col='country')
dataframe
# Out:
#                          continent  gdpPercap_1952  gdpPercap_1957  \
# country
# Algeria                     Africa     2449.008185     3013.976023
# Angola                      Africa     3520.610273     3827.940465
# Benin                       Africa     1062.752200      959.601080
# Botswana                    Africa      851.241141      918.232535
# Burkina Faso                Africa      543.255241      617.183465
# Burundi                     Africa      339.296459      379.564628
# Cameroon                    Africa     1172.667655     1313.048099
# Central African Republic    Africa     1071.310713     1190.844328
# Chad                        Africa     1178.665927     1308.495577
# Comoros                     Africa     1102.990936     1211.148548
# Congo Dem. Rep.             Africa      780.542326      905.860230
# Congo Rep.                  Africa     2125.621418     2315.056572
# Cote d'Ivoire               Africa     1388.594732     1500.895925
# ...

# %%
dataframe.iloc[0:4,6:]
# Out:
#           gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# Algeria      4910.416756     5745.160213     5681.358539     5023.216647
# Angola       3008.647355     2756.953672     2430.208311     2627.845685
# Benin        1029.161251     1277.897616     1225.856010     1191.207681
# Botswana     3214.857818     4551.142150     6205.883850     7954.111645
#
#           gdpPercap_1997  gdpPercap_2002  gdpPercap_2007  lifeExp_1952  \
# country
# Algeria      4797.295051     5288.040382     6223.367465        43.077
# Angola       2277.140884     2773.287312     4797.231267        30.015
# Benin        1232.975292     1372.877931     1441.284873        38.223
# Botswana     8647.142313    11003.605080    12569.851770        47.622
#
#           lifeExp_1957  lifeExp_1962    ...       pop_1962    pop_1967  \
# country                                 ...
# Algeria         45.685        48.303    ...     11000948.0  12760499.0
# ...

# %%
dataframe.loc['Switzerland','gdpPercap_1997']
# Out:
# 32135.323010000004

# %% [markdown]
# ### iloc integer location
# ### loc name location

# %%
dataframe.loc['Switzerland':,'gdpPercap_1977':'gdpPercap_2002']
# Out:
#                 gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Switzerland       26982.290520    28397.715120    30281.704590
# Turkey             4269.122326     4241.356344     5089.043686
# United Kingdom    17428.748460    18232.424520    21664.787670
# Australia         18334.197510    19477.009280    21888.889030
# New Zealand       16233.717700    17632.410400    19007.191290
#
#                 gdpPercap_1992  gdpPercap_1997  gdpPercap_2002
# country
# Switzerland       31871.530300    32135.323010    34480.957710
# Turkey             5678.348271     6601.429915     6508.085718
# United Kingdom    22705.092540    26074.531360    29478.999190
# Australia         23424.766830    26997.936570    30687.754730
# New Zealand       18363.324940    21050.413770    23189.801350

# %% [markdown]
# ### mask

# %%
dataframe.mean().mean()
# Out:
# 9869495.708879314

# %%
global_mean=dataframe.mean().mean()
dataframe>global_mean
# Out:
#                           continent  gdpPercap_1952  gdpPercap_1957  \
# country
# Algeria                        True           False           False
# Angola                         True           False           False
# Benin                          True           False           False
# Botswana                       True           False           False
# Burkina Faso                   True           False           False
# Burundi                        True           False           False
# Cameroon                       True           False           False
# Central African Republic       True           False           False
# Chad                           True           False           False
# Comoros                        True           False           False
# Congo Dem. Rep.                True           False           False
# Congo Rep.                     True           False           False
# Cote d'Ivoire                  True           False           False
# ...

# %%
global_mean=dataframe.mean().mean()
greater_than_mean_mask=dataframe>global_mean
dataframe[greater_than_mean_mask].describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count             0.0             0.0             0.0             0.0
# mean              NaN             NaN             NaN             NaN
# std               NaN             NaN             NaN             NaN
# min               NaN             NaN             NaN             NaN
# 25%               NaN             NaN             NaN             NaN
# 50%               NaN             NaN             NaN             NaN
# 75%               NaN             NaN             NaN             NaN
# max               NaN             NaN             NaN             NaN
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count             0.0             0.0             0.0             0.0
# mean              NaN             NaN             NaN             NaN
# std               NaN             NaN             NaN             NaN
# ...

# %% [markdown]
# NaN: not a number
